# %% [markdown]
# # Convert from TEI to TF to WATM
#
# First we convert Mondriaan TEI to TF and then the TF to WATM.
#
# This notebook is bare, no explanations, no illustrations, no checks.
# For more documentation, try any of the following variants:
#
# * `convertExpress` : as few commands/feedback/interaction as possible,
# * [convertSteps](convertSteps.ipynb): broken down in a few command line commands, more feedback
# * [convertDetails](convertDetails.ipynb): run from Python with full control

# %% [markdown]
# # One shot
#
# Here is the express, mindless way to convert the corpus.
#
# If something goes wrong, you can follow the rest of the notebook.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from make import run

# %%
# %%time

run("all 0.0.1 --silent")
# Out:
# Using TF version: 0.8.15
# WARNING: section model property drillDownDivs not specified, taking default True
# Checking TEI ...
# 	folder proeftuin:
# 	folder backmatter:
# Converting TEI to TF ...
# 	folder proeftuin:
# 	folder backmatter:
# Loading TF ...
# App updated
# Add tokens and sentences ...
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
#   0.21s Using NLP pipeline Spacy (it) ...
# NLP with language model it True
# This language supports tagging
# This language supports morphologizing
# This language supports lemmatizing
#   4.95s NLP done
#   0.00s Feature overview: 65 for nodes; 5 for edges; 1 configs; 9 computed
# App updated with NLP output
# Producing WATM
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# WARNING: 26 discontinuous nodes encountered
# 	16 x of type sentence
# 	4 x of type ent
# 	6 x of type token
# WARNING: targets across tier0 items, 2x
# OK - whether all tests passed
# CPU times: user 12.1 s, sys: 1.16 s, total: 13.3 s
# Wall time: 14.1 s

# %% [markdown]
# # Only WATM:

# %%
# %%time

run("watm 0.0.1 --silent")
# Out:
# Using TF version: 0.8.14
# Producing WATM
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# WARNING: 26 discontinuous nodes encountered
# 	16 x of type sentence
# 	4 x of type ent
# 	6 x of type token
# WARNING: targets across tier0 items, 2x
# OK - whether all tests passed
# CPU times: user 755 ms, sys: 32 ms, total: 787 ms
# Wall time: 787 ms

# %% [markdown]
# # Step by step
#
# Below you can inspect all the steps of the conversion:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from tf.convert.tei import TEI
from tf.convert.addnlp import NLPipeline
from tf.convert.watm import WATM
from tf.advanced.helpers import dm

# %%
MINI = False
Tei = TEI(verbose=-1, tei="2024-01-01", tf="0.0.1pre") if MINI else TEI(
    verbose=-1, tei=0, tf="0.1.0pre"
)

# %% [markdown]
# # Step 1: Check

# %%
Tei.task(check=True, verbose=1, validate=True)
# Out:
# TEI to TF checking: ~/gitlab.huc.knaw.nl/van-gogh/letters/tei/2024-01-01 => ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01
# Processing instructions are treated
# XML validation will be performed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# INFO: Needs ns2.xsd (exists)
# INFO: Needs ns1.xsd (exists)
# INFO: Needs dcr.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/MD.xsd
# 	round   1:  45 changes
# 172 identical override(s)
#   4 changing override(s)
# 	address pure ==> mixed
# 	postmark complex mixed (added)
# 	rewrite complex mixed (added)
# 	transpose pure ==> mixed
# INFO: Needs artwork1.xsd (exists)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/artwork.xsd
# 	round   1:  15 changes
# 	round   2:   2 changes
#  24 identical override(s)
#   3 changing override(s)
# 	artwork complex pure (added)
# 	bibl mixed ==> pure
# 	catRef pure ==> mixed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/bio.xsd
# 	round   1:  19 changes
#  30 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/biblio.xsd
# 	round   1:   7 changes
#  17 identical override(s)
#   0 changing override(s)
# Section model I
# Start folder letters:
#    1 MD           letter       vg           0010.xml
#    2 MD           letter       vg           0011.xml
#    3 MD           letter       vg           0020.xml
#    4 MD           letter       vg           0030.xml
#    5 MD           letter       vg           0040.xml
#
# End   folder letters
# Start folder rm:
#    6 MD           letter       vg           0010.xml
#    7 MD           letter       vg           0020.xml
#
# End   folder rm
# Start folder apparatus:
#    8 bio          biolist                   bio.xml
#
# End   folder apparatus
# 7 MD file(s) ...
# 	Validating ...
# 		Elapsed time 130+54=184 milliseconds
# 	Making inventory ...
# 1 bio file(s) ...
# 	Validating ...
# 		Elapsed time 104+26=130 milliseconds
# 	Making inventory ...
# 1 validation error(s) in 1 file(s) written to ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01/errors.txt
# 167 info line(s) written to ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01/elements.txt
# 587 tag(s) type info written to ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01/types.txt
# 0 processing instructions encountered.
# 50 tags of which 0 with multiple namespaces written to ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01/namespaces.txt
# Refs written to ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01/refs.txt
# 	resolvable:   37 in   74
# 	dangling:     56 in  122
# 	ALL:          93 in  196
# Ids written to ~/gitlab.huc.knaw.nl/van-gogh/letters/report/2024-01-01/ids.txt
# 	referenced:   37 by   74
# 	non-unique:   30
# 	unused:      249
# 	ALL:         256 in  286
# False

# %% [markdown]
# # Step 2: Convert

# %%
Tei.good = True
Tei.task(convert=True, verbose=0)
# Out:
# Processing instructions are treated
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/MD.xsd
# 	round   1:  45 changes
# 172 identical override(s)
#   4 changing override(s)
# 	address pure ==> mixed
# 	postmark complex mixed (added)
# 	rewrite complex mixed (added)
# 	transpose pure ==> mixed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/artwork.xsd
# 	round   1:  15 changes
# 	round   2:   2 changes
#  24 identical override(s)
#   3 changing override(s)
# 	artwork complex pure (added)
# 	bibl mixed ==> pure
# 	catRef pure ==> mixed
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/bio.xsd
# 	round   1:  19 changes
#  30 identical override(s)
#   0 changing override(s)
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
# 	round   1: 232 changes
# Analysing ~/gitlab.huc.knaw.nl/van-gogh/letters/schema/biblio.xsd
# 	round   1:   7 changes
#  17 identical override(s)
#   0 changing override(s)
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s OK
#    |     0.00s Following director...
# Start folder letters:
#    1 MD           vg           letter       0010.xml
#    2 MD           vg           letter       0011.xml
#    3 MD           vg           letter       0020.xml
#    4 MD           vg           letter       0030.xml
#    5 MD           vg           letter       0040.xml
#
# End   folder letters
# Start folder rm:
#    6 MD           vg           letter       0010.xml
#    7 MD           vg           letter       0020.xml
#
# End   folder rm
# Start folder apparatus:
#    8 bio                       biolist      bio.xml
#
# End   folder apparatus
#
# Resolving links into edges ...
# 	37 in 74 reference(s) resolved
# 	56 in 122 reference(s): could not be resolved
#    |     0.14s "delete" actions: 0
#    |     0.14s "edge" actions: 1079
#    |     0.14s "feature" actions: 72636
#    |     0.14s "node" actions: 6946
#    |     0.14s "resume" actions: 0
#    |     0.14s "slot" actions: 30633
#    |     0.14s "terminate" actions: 6953
#    |      37579 nodes of all types
#    |     0.14s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.02s Max node = 37579
#    |     0.02s OK
#    |     0.00s reassigning feature values ...
#    |     0.01s OK
# True

# %% [markdown]
# # Step 3: Load the TF data
#
# The final proof that the conversion has worked is to load the data.
# On first-time loading several checks and pre-computations are performed.
# Next time the loading will be much quicker.

# %%
Tei.task(load=True, verbose=1)
# Out:
#    |     0.01s T otype                from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |     0.11s T oslots               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |     0.00s T chunk                from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |     0.06s T ch                   from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |     0.00s T file                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |     0.00s T folder               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s C __levels__           from otype, oslots, otext
#    |      |     0.28s C __order__            from otype, oslots, __levels__
#    |      |     0.01s C __rank__             from otype, __order__
#    |      |     0.27s C __levUp__            from otype, oslots, __rank__
#    |      |     0.06s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.00s C __characters__       from otext
#    |      |     0.06s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, folder, file, chunk
#    |      |     0.01s T after                from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T artref               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T correspondent        from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T empty                from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T extraspace           from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T f                    from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T facs                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T full                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T id                   from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T institution          from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.01s T is_meta              from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.03s T is_note              from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T lang                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T letterid             from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T link_target          from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T location             from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T msid                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T n                    from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T parent               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T period               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T periodlong           from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T personref            from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T quantity             from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T ref                  from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T rend                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.02s T rend_indent          from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T rend_italics         from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T rend_super           from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T sex                  from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T status               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.01s T str                  from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T target               from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T type                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T unit                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T url                  from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
#    |      |     0.00s T when                 from ~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre
# max node = 37579
# True

# %% [markdown]
# # Step 4: Configure a TF app
#
# The TF app has configuration settings, a bit of custom code, and documentation.
# Most of it will be generated now, but there are ways to keep custom additions intact.

# %%
Tei.task(app=True)
# Out:
# App updated
# True

# %% [markdown]
# # Step 5: Add tokens and sentences

# %%
Apre = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/van-gogh/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.3.6</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/app" title="van-gogh/letters app">van-gogh/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/about.md" title="provenance of van-gogh - letters/tf">van-gogh - letters 0.0.1pre</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="van-gogh - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>3</td>
#     <td>10211.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>7</td>
#     <td>4359.57</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>8</td>
#     <td>3829.12</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>8</td>
#     <td>2136.50</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>8</td>
#     <td>2136.50</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>7</td>
#     <td>1529.29</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>14</td>
#     <td>1216.21</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>32</td>
#     <td>532.09</td>
#     <td>56</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>21</td>
#     <td>509.71</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>8</td>
#     <td>284.12</td>
#     <td>7</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>8</td>
#     <td>145.38</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>biolist</th>
#     <td>1</td>
#     <td>116.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>269</td>
#     <td>113.79</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>8</td>
#     <td>343.88</td>
#     <td>9</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>255</td>
#     <td>109.75</td>
#     <td>91</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>57</td>
#     <td>188.09</td>
#     <td>35</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>8</td>
#     <td>97.12</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>availability</th>
#     <td>7</td>
#     <td>75.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>licence</th>
#     <td>7</td>
#     <td>75.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>7</td>
#     <td>66.29</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>7</td>
#     <td>66.29</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>listPerson</th>
#     <td>1</td>
#     <td>65.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>person</th>
#     <td>1</td>
#     <td>64.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>8</td>
#     <td>63.88</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>7</td>
#     <td>54.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>7</td>
#     <td>44.86</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>7</td>
#     <td>44.86</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>8</td>
#     <td>41.62</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>persName</th>
#     <td>1</td>
#     <td>39.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publisher</th>
#     <td>14</td>
#     <td>35.50</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>14</td>
#     <td>33.14</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>surname</th>
#     <td>1</td>
#     <td>28.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>14</td>
#     <td>15.79</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>7</td>
#     <td>14.43</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>99</td>
#     <td>13.64</td>
#     <td>4</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>21</td>
#     <td>12.67</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>7</td>
#     <td>11.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>36</td>
#     <td>10.72</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>7</td>
#     <td>10.14</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pubPlace</th>
#     <td>7</td>
#     <td>10.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>17</td>
#     <td>9.53</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>7</td>
#     <td>8.29</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>forename</th>
#     <td>1</td>
#     <td>7.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>supplied</th>
#     <td>8</td>
#     <td>5.75</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>14</td>
#     <td>5.07</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>28</td>
#     <td>4.79</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>5591</td>
#     <td>4.27</td>
#     <td>78</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>21</td>
#     <td>3.19</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>19</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>c</th>
#     <td>24</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>figure</th>
#     <td>2</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>floruit</th>
#     <td>1</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>33</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>32</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>81</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>50</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>char</i></th>
#     <td>30633</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>van-gogh - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the text after a word till the next word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre/artref.tf">artref</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Reference key to the details of an artwork; the content is taken from rs@ref[type=artwork]</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre/ch.tf">ch</a>
# </div>
# <div class="fmono">str</div>
#
# <span> the UNICODE character of a slot</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre/chunk.tf">chunk</a>
# </div>
# <div class="fmono">int</div>
#
# <span> number of a chunk within a document</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.0.1pre/correspondent.tf">correspondent</a>
# </div>
# <div class="fmono">str</div>
#
# <span> The person that Mondriaan corresponded with; the content is taken from profileDesc/correspDesc/correspAction[type=received]/rs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %%
NLP = NLPipeline(lang="en", verbose=0, write=True)
NLP.loadApp(Apre)
# Out:
# Input data has version 0.0.1pre
# Compute element boundaries
#    822 start positions
#    938 end positions

# %%
NLP.task(plaintext=True, lingo=True, ingest=True)
# Out:
# Input data has version 0.0.1pre
# Compute element boundaries
#    822 start positions
#    938 end positions
#   0.00s Generating a plain text with positions ...
# Analysing ~/github/annotation/text-fabric/tf/tools/tei/tei_all.xsd
#    |   Found 201 empty slots
#    |   recorded flow main       with  61538 items
#    |   recorded flow note       with  32405 items
#   0.11s Done. Generated text and positions written to ~/gitlab.huc.knaw.nl/van-gogh/letters/_temp/txt/0.0.1pre/plain.txt
#   0.11s Using NLP pipeline Spacy (en) ...
# NLP with language model en False
#   2.66s Tokens written to ~/gitlab.huc.knaw.nl/van-gogh/letters/_temp/txt/0.0.1pre/tokens.tsv
#   2.66s Sentences written to ~/gitlab.huc.knaw.nl/van-gogh/letters/_temp/txt/0.0.1pre/sentences.tsv
#   2.66s NLP done
#   2.66s Ingesting NLP output into the dataset ...
#    |     3.87s Mapping NLP data to nodes and features ...
#    |      |     0.00s generating t-nodes with features str, after, empty
#    |      |      |    -0.00s 7251 t nodes have values assigned for str, after, pos, morph, lemma
#    |      |      |     0.00s 0 empty slots are properly contained in a token
#    |      |      |     0.00s 90 space slots have split into chars
#    |      |      |     0.00s 1023 slots have split around an element boundary
#    |      |      |     0.00s  9411x Items contained in extra generated text
#    |      |     0.03s 6996 tokens
#    |      |     0.03s 7251 ts
#    |      |     0.03s generating sentence-nodes with features nsent
#    |      |      |     0.01s 653 sentence nodes have values assigned for nsent
#    |      |      |     0.01s  1361x Items contained in extra generated text
#    |      |      |     0.01s    79x Items with empty final text
#    |      |     0.04s 653 sentences
#    |     3.91s Make a modified dataset ...
#   0.00s Feature overview: 39 for nodes; 3 for edges; 1 configs; 9 computed
#    |     4.11s Done
#   2.90s Enriched data is available in version 0.0.1
# You may need to adapt this TF app and its documentation:
# please run: python tfFromTei.py apptoken
# '0.0.1'

# %%
Tei.task(apptoken=True)
# Out:
# App updated with NLP output
# True

# %% [markdown]
# # Step 6: Use the new dataset

# %%
A = use(f"{Tei.org}/{Tei.repo}:clone", backend=Tei.backend, checkout="clone", silent="verbose", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/van-gogh/letters/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/gitlab.huc.knaw.nl">~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.1.0</span>
# This is Text-Fabric 12.3.6
# 49 features found and 0 ignored
#   1.97s Dataset without structure sections in otext:no structure functions in the T-API
#   6.14s All features loaded / computed - for details use TF.isLoaded()
#   0.35s All additional features loaded - for details use TF.isLoaded()
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.3.6</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/app" title="van-gogh/letters app">van-gogh/letters/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/about.md" title="provenance of van-gogh - letters/tf">van-gogh - letters 0.1.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="van-gogh - letters feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>folder</th>
#     <td>3</td>
#     <td>1087728.67</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>artworklist</th>
#     <td>1</td>
#     <td>55287.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>listObject</th>
#     <td>1</td>
#     <td>55261.00</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>bibliolist</th>
#     <td>1</td>
#     <td>27621.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>listBibl</th>
#     <td>1</td>
#     <td>27466.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>biolist</th>
#     <td>1</td>
#     <td>22954.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>listPerson</th>
#     <td>1</td>
#     <td>22943.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>file</th>
#     <td>931</td>
#     <td>3505.03</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>letter</th>
#     <td>928</td>
#     <td>3402.29</td>
#     <td>97</td>
# </tr>
#
# <tr>
#     <th>body</th>
#     <td>931</td>
#     <td>2549.17</td>
#     <td>73</td>
# </tr>
#
# <tr>
#     <th>text</th>
#     <td>931</td>
#     <td>2549.17</td>
#     <td>73</td>
# </tr>
#
# <tr>
#     <th>div</th>
#     <td>1856</td>
#     <td>1221.71</td>
#     <td>69</td>
# </tr>
#
# <tr>
#     <th>standOff</th>
#     <td>928</td>
#     <td>842.88</td>
#     <td>24</td>
# </tr>
#
# <tr>
#     <th>listAnnotation</th>
#     <td>2784</td>
#     <td>280.96</td>
#     <td>24</td>
# </tr>
#
# <tr>
#     <th>page</th>
#     <td>8260</td>
#     <td>274.51</td>
#     <td>69</td>
# </tr>
#
# <tr>
#     <th>fileDesc</th>
#     <td>931</td>
#     <td>79.62</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>chunk</th>
#     <td>62116</td>
#     <td>52.47</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>teiHeader</th>
#     <td>931</td>
#     <td>100.11</td>
#     <td>3</td>
# </tr>
#
# <tr>
#     <th>p</th>
#     <td>63046</td>
#     <td>47.55</td>
#     <td>92</td>
# </tr>
#
# <tr>
#     <th>note</th>
#     <td>19887</td>
#     <td>40.51</td>
#     <td>25</td>
# </tr>
#
# <tr>
#     <th>publicationStmt</th>
#     <td>931</td>
#     <td>36.90</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>titleStmt</th>
#     <td>931</td>
#     <td>26.07</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>bibl</th>
#     <td>1260</td>
#     <td>21.80</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspDesc</th>
#     <td>928</td>
#     <td>18.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>profileDesc</th>
#     <td>928</td>
#     <td>18.56</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>artwork</th>
#     <td>2920</td>
#     <td>18.27</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>availability</th>
#     <td>928</td>
#     <td>18.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>licence</th>
#     <td>928</td>
#     <td>18.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>180220</td>
#     <td>17.19</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>msDesc</th>
#     <td>928</td>
#     <td>16.67</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>msIdentifier</th>
#     <td>928</td>
#     <td>16.67</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>sourceDesc</th>
#     <td>931</td>
#     <td>16.65</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>facsimile</th>
#     <td>928</td>
#     <td>13.65</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>person</th>
#     <td>1791</td>
#     <td>11.81</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>title</th>
#     <td>2245</td>
#     <td>11.16</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>correspAction</th>
#     <td>1856</td>
#     <td>9.28</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>head</th>
#     <td>2922</td>
#     <td>8.80</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>name</th>
#     <td>928</td>
#     <td>8.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>publisher</th>
#     <td>1856</td>
#     <td>6.50</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>persName</th>
#     <td>1791</td>
#     <td>5.62</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surface</th>
#     <td>2585</td>
#     <td>4.90</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>institution</th>
#     <td>928</td>
#     <td>3.93</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>date</th>
#     <td>3100</td>
#     <td>3.81</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ref</th>
#     <td>11871</td>
#     <td>3.73</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>editor</th>
#     <td>2784</td>
#     <td>3.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>hi</th>
#     <td>25992</td>
#     <td>2.94</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>placeName</th>
#     <td>928</td>
#     <td>2.80</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>label</th>
#     <td>1260</td>
#     <td>2.70</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>idno</th>
#     <td>3705</td>
#     <td>2.68</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>zone</th>
#     <td>4219</td>
#     <td>2.39</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>rs</th>
#     <td>29418</td>
#     <td>2.26</td>
#     <td>2</td>
# </tr>
#
# <tr>
#     <th>supplied</th>
#     <td>172</td>
#     <td>2.10</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>forename</th>
#     <td>1791</td>
#     <td>2.06</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>settlement</th>
#     <td>921</td>
#     <td>2.03</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>altIdentifier</th>
#     <td>2784</td>
#     <td>2.01</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pubPlace</th>
#     <td>928</td>
#     <td>2.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>surname</th>
#     <td>1791</td>
#     <td>1.56</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>token</th>
#     <td>3159438</td>
#     <td>1.01</td>
#     <td>98</td>
# </tr>
#
# <tr>
#     <th>birth</th>
#     <td>1668</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>c</th>
#     <td>46026</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>death</th>
#     <td>1640</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>figure</th>
#     <td>499</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>graphic</th>
#     <td>10708</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>measure</th>
#     <td>1274</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>pb</th>
#     <td>8260</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>ptr</th>
#     <td>24430</td>
#     <td>1.00</td>
#     <td>1</td>
# </tr>
#
# <tr>
#     <th>relation</th>
#     <td>2694</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>space</th>
#     <td>7295</td>
#     <td>1.00</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th><i>t</i></th>
#     <td>3263186</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>van-gogh - letters/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://gitlab.huc.knaw.nl/van-gogh/letters/blob/main/docs/transcription.md" title="~/gitlab.huc.knaw.nl/van-gogh/letters/tf/0.1.0/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <details>
#     <summary>the whitespace after the token</summary>
#     <div class="fmeta">
#
# <div class="fmetarow">
#     <div class="fmetakey">author:</div>
#     <div>Vincent van Gogh</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors1:</div>
#     <div>Hennie Brugman, Hayco de Jong, Bram Buitendijk, Sebastiaan van Daalen, Dirk Roorda</div>
# </div>
#
# <div class="fmetarow">
#     <div class="fmetakey">contributors2:</div>
#     <div>Leo Jansen, Peter Boot, Beatric
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %%
T.sectionTypes
# Out:
# ['folder', 'file', 'chunk']

# %% [markdown]
# # Step 7 Convert to WATM

# %% [markdown]
# N.B. For docs click the WATM link in the output cell.

# %%
WA = WATM(A, "tei", skipMeta=False, extra=dict())
WA.makeText()
# Out:
# textRepoLevel is section level 'file'
# [WATM exporter documentation](https://annotation.github.io/text-fabric/tf/convert/watm.html)

# %%
WA.makeAnno()
# Out:
# WARNING: targets across tier0 items, 3x
#               folder [   0:     0] - [ 902:  2552]
#               folder [ 903:     0] - [ 927:  1229]
#               folder [ 928:     0] - [ 930: 22952]

# %%
WA.writeAll()
# Out:
# Text file    0:      842 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-0.tsv
# Text file    1:      905 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-1.tsv
# Text file    2:      624 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-2.tsv
# Text file    3:     1831 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-3.tsv
# Text file    4:     1743 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-4.tsv
# Text file    5:     2182 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-5.tsv
# Text file    6:      643 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-6.tsv
# Text file    7:      828 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-7.tsv
# Text file    8:      757 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-8.tsv
# Text file    9:     2026 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-9.tsv
# Text file   10:     3743 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-10.tsv
# Text file   11:     5462 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-11.tsv
# Text file   12:     4427 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-12.tsv
# Text file   13:     2159 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-13.tsv
# Text file   14:     3905 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-14.tsv
# Text file   15:     2490 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-15.tsv
# Text file   16:      551 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-16.tsv
# Text file   17:     1965 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-17.tsv
# Text file   18:      717 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-18.tsv
# Text file   19:     1812 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-19.tsv
# Text file   20:      719 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-20.tsv
# Text file   21:      820 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-21.tsv
# Text file   22:     1558 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-22.tsv
# Text file   23:      967 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-23.tsv
# Text file   24:      782 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-24.tsv
# Text file   25:      487 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-25.tsv
# Text file   26:      970 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-26.tsv
# Text file   27:     2278 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-27.tsv
# Text file   28:     1786 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-28.tsv
# Text file   29:     1907 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-29.tsv
# Text file   30:     1245 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-30.tsv
# Text file   31:     1332 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-31.tsv
# Text file   32:     1426 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-32.tsv
# Text file   33:     1579 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-33.tsv
# Text file   34:     1638 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-34.tsv
# Text file   35:     1368 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-35.tsv
# Text file   36:     1619 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-36.tsv
# Text file   37:     2791 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-37.tsv
# Text file   38:     2190 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-38.tsv
# Text file   39:     1185 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-39.tsv
# Text file   40:     2529 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-40.tsv
# Text file   41:     1538 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-41.tsv
# Text file   42:     1925 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-42.tsv
# Text file   43:      688 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-43.tsv
# Text file   44:      707 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-44.tsv
# Text file   45:      714 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-45.tsv
# Text file   46:      917 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-46.tsv
# Text file   47:     1094 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-47.tsv
# Text file   48:      438 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-48.tsv
# Text file   49:     1025 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-49.tsv
# Text file   50:     1469 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-50.tsv
# Text file   51:     1639 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-51.tsv
# Text file   52:      714 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-52.tsv
# Text file   53:      936 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-53.tsv
# Text file   54:     3253 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-54.tsv
# Text file   55:     3276 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-55.tsv
# Text file   56:     1354 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-56.tsv
# Text file   57:      850 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-57.tsv
# Text file   58:      733 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-58.tsv
# Text file   59:      881 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-59.tsv
# Text file   60:     1100 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-60.tsv
# Text file   61:     1438 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-61.tsv
# Text file   62:     1270 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-62.tsv
# Text file   63:      514 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-63.tsv
# Text file   64:      753 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-64.tsv
# Text file   65:     1759 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-65.tsv
# Text file   66:     2152 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-66.tsv
# Text file   67:     1257 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-67.tsv
# Text file   68:      768 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-68.tsv
# Text file   69:     1206 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-69.tsv
# Text file   70:     1622 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-70.tsv
# Text file   71:     1218 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-71.tsv
# Text file   72:     1231 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-72.tsv
# Text file   73:     1427 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-73.tsv
# Text file   74:     2417 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-74.tsv
# Text file   75:      405 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-75.tsv
# Text file   76:     3349 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-76.tsv
# Text file   77:      908 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-77.tsv
# Text file   78:     1848 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-78.tsv
# Text file   79:     1289 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-79.tsv
# Text file   80:     1408 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-80.tsv
# Text file   81:     1183 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-81.tsv
# Text file   82:     1904 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-82.tsv
# Text file   83:     1788 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-83.tsv
# Text file   84:     3449 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-84.tsv
# Text file   85:     4644 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-85.tsv
# Text file   86:     1731 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-86.tsv
# Text file   87:     8423 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-87.tsv
# Text file   88:     3527 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-88.tsv
# Text file   89:     8611 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-89.tsv
# Text file   90:     7746 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-90.tsv
# Text file   91:      801 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-91.tsv
# Text file   92:     5953 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-92.tsv
# Text file   93:     7757 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-93.tsv
# Text file   94:     7834 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-94.tsv
# Text file   95:     4325 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-95.tsv
# Text file   96:    11834 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-96.tsv
# Text file   97:     1850 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-97.tsv
# Text file   98:     3250 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-98.tsv
# Text file   99:     4538 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-99.tsv
# Text file  100:     2326 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-100.tsv
# Text file  101:     3485 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-101.tsv
# Text file  102:     6100 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-102.tsv
# Text file  103:     3942 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-103.tsv
# Text file  104:    12758 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-104.tsv
# Text file  105:     1225 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-105.tsv
# Text file  106:     2090 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-106.tsv
# Text file  107:     1263 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-107.tsv
# Text file  108:     2924 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-108.tsv
# Text file  109:     4034 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-109.tsv
# Text file  110:     2770 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-110.tsv
# Text file  111:     2631 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-111.tsv
# Text file  112:     3061 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-112.tsv
# Text file  113:     2713 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-113.tsv
# Text file  114:     5215 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-114.tsv
# Text file  115:     4155 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-115.tsv
# Text file  116:     2303 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-116.tsv
# Text file  117:     4211 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-117.tsv
# Text file  118:    14645 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-118.tsv
# Text file  119:     9166 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-119.tsv
# Text file  120:     6737 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-120.tsv
# Text file  121:     2122 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-121.tsv
# Text file  122:     3625 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-122.tsv
# Text file  123:     3834 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-123.tsv
# Text file  124:     4112 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-124.tsv
# Text file  125:     4411 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-125.tsv
# Text file  126:     5454 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-126.tsv
# Text file  127:     5444 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-127.tsv
# Text file  128:     4443 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-128.tsv
# Text file  129:     6650 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-129.tsv
# Text file  130:     2642 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-130.tsv
# Text file  131:     6957 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-131.tsv
# Text file  132:     4349 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-132.tsv
# Text file  133:     9039 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-133.tsv
# Text file  134:     6690 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-134.tsv
# Text file  135:     6986 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-135.tsv
# Text file  136:     8851 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-136.tsv
# Text file  137:     5975 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-137.tsv
# Text file  138:     1991 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-138.tsv
# Text file  139:     3858 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-139.tsv
# Text file  140:     3182 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-140.tsv
# Text file  141:     6031 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-141.tsv
# Text file  142:     3663 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-142.tsv
# Text file  143:     7367 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-143.tsv
# Text file  144:     3913 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-144.tsv
# Text file  145:     6991 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-145.tsv
# Text file  146:     2231 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-146.tsv
# Text file  147:     1245 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-147.tsv
# Text file  148:     8168 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-148.tsv
# Text file  149:     4717 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-149.tsv
# Text file  150:     3399 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-150.tsv
# Text file  151:     3856 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-151.tsv
# Text file  152:     4653 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-152.tsv
# Text file  153:     3349 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-153.tsv
# Text file  154:     4965 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-154.tsv
# Text file  155:    12906 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-155.tsv
# Text file  156:     3103 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-156.tsv
# Text file  157:     4193 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-157.tsv
# Text file  158:     8346 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-158.tsv
# Text file  159:     3462 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-159.tsv
# Text file  160:     4675 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-160.tsv
# Text file  161:     1486 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-161.tsv
# Text file  162:     2949 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-162.tsv
# Text file  163:     3642 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-163.tsv
# Text file  164:     7993 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-164.tsv
# Text file  165:      796 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-165.tsv
# Text file  166:     3218 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-166.tsv
# Text file  167:     1040 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-167.tsv
# Text file  168:     2885 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-168.tsv
# Text file  169:     1411 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-169.tsv
# Text file  170:     3319 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-170.tsv
# Text file  171:     4874 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-171.tsv
# Text file  172:     3362 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-172.tsv
# Text file  173:     1261 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-173.tsv
# Text file  174:     2684 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-174.tsv
# Text file  175:     3268 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-175.tsv
# Text file  176:     5069 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-176.tsv
# Text file  177:     2141 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-177.tsv
# Text file  178:     3452 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-178.tsv
# Text file  179:     3960 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-179.tsv
# Text file  180:     5567 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-180.tsv
# Text file  181:     8671 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-181.tsv
# Text file  182:     5314 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-182.tsv
# Text file  183:     9154 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-183.tsv
# Text file  184:     6579 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-184.tsv
# Text file  185:     2861 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-185.tsv
# Text file  186:     5887 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-186.tsv
# Text file  187:     8706 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-187.tsv
# Text file  188:     3972 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-188.tsv
# Text file  189:    12014 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-189.tsv
# Text file  190:     3884 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-190.tsv
# Text file  191:     1781 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-191.tsv
# Text file  192:     3410 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-192.tsv
# Text file  193:    15107 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-193.tsv
# Text file  194:     3317 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-194.tsv
# Text file  195:     1555 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-195.tsv
# Text file  196:     1716 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-196.tsv
# Text file  197:     1082 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-197.tsv
# Text file  198:     1134 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-198.tsv
# Text file  199:     8323 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-199.tsv
# Text file  200:     3308 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-200.tsv
# Text file  201:     2751 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-201.tsv
# Text file  202:     2616 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-202.tsv
# Text file  203:     3804 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-203.tsv
# Text file  204:     2579 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-204.tsv
# Text file  205:      919 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-205.tsv
# Text file  206:     2597 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-206.tsv
# Text file  207:     2647 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-207.tsv
# Text file  208:     2102 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-208.tsv
# Text file  209:     2619 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-209.tsv
# Text file  210:     4664 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-210.tsv
# Text file  211:     6891 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-211.tsv
# Text file  212:     5812 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-212.tsv
# Text file  213:     1916 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-213.tsv
# Text file  214:     4864 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-214.tsv
# Text file  215:     3546 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-215.tsv
# Text file  216:     2260 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-216.tsv
# Text file  217:     3060 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-217.tsv
# Text file  218:     1858 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-218.tsv
# Text file  219:     4087 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-219.tsv
# Text file  220:     4008 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-220.tsv
# Text file  221:     3424 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-221.tsv
# Text file  222:     7305 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-222.tsv
# Text file  223:      686 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-223.tsv
# Text file  224:     3553 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-224.tsv
# Text file  225:     3393 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-225.tsv
# Text file  226:     4034 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-226.tsv
# Text file  227:     6385 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-227.tsv
# Text file  228:    11259 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-228.tsv
# Text file  229:     1976 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-229.tsv
# Text file  230:     2542 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-230.tsv
# Text file  231:     2182 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-231.tsv
# Text file  232:     3995 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-232.tsv
# Text file  233:      882 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-233.tsv
# Text file  234:    12332 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-234.tsv
# Text file  235:     6760 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-235.tsv
# Text file  236:     1961 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-236.tsv
# Text file  237:     3475 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-237.tsv
# Text file  238:     1975 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-238.tsv
# Text file  239:     4550 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-239.tsv
# Text file  240:     1802 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-240.tsv
# Text file  241:     3635 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-241.tsv
# Text file  242:     2197 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-242.tsv
# Text file  243:     2272 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-243.tsv
# Text file  244:     9047 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-244.tsv
# Text file  245:     5879 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-245.tsv
# Text file  246:     8262 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-246.tsv
# Text file  247:     6957 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-247.tsv
# Text file  248:     4048 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-248.tsv
# Text file  249:     3366 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-249.tsv
# Text file  250:     6220 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-250.tsv
# Text file  251:     6191 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-251.tsv
# Text file  252:     6129 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-252.tsv
# Text file  253:     3048 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-253.tsv
# Text file  254:     1904 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-254.tsv
# Text file  255:     2680 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-255.tsv
# Text file  256:     3506 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-256.tsv
# Text file  257:     3397 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-257.tsv
# Text file  258:     7883 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-258.tsv
# Text file  259:     4836 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-259.tsv
# Text file  260:     5063 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-260.tsv
# Text file  261:     3420 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-261.tsv
# Text file  262:     2878 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-262.tsv
# Text file  263:     2502 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-263.tsv
# Text file  264:     2618 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-264.tsv
# Text file  265:     4161 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-265.tsv
# Text file  266:     3112 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-266.tsv
# Text file  267:     8208 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-267.tsv
# Text file  268:     2979 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-268.tsv
# Text file  269:     3595 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-269.tsv
# Text file  270:     2545 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-270.tsv
# Text file  271:     1589 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-271.tsv
# Text file  272:     4898 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-272.tsv
# Text file  273:     4715 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-273.tsv
# Text file  274:     5019 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-274.tsv
# Text file  275:     7662 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-275.tsv
# Text file  276:     4119 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-276.tsv
# Text file  277:     3615 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-277.tsv
# Text file  278:     3942 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-278.tsv
# Text file  279:     4453 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-279.tsv
# Text file  280:     7557 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-280.tsv
# Text file  281:     2918 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-281.tsv
# Text file  282:     2981 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-282.tsv
# Text file  283:     2843 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-283.tsv
# Text file  284:     3983 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-284.tsv
# Text file  285:     2687 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-285.tsv
# Text file  286:     3939 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-286.tsv
# Text file  287:     3012 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-287.tsv
# Text file  288:     7439 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-288.tsv
# Text file  289:     5346 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-289.tsv
# Text file  290:     6285 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-290.tsv
# Text file  291:     7048 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-291.tsv
# Text file  292:     5286 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-292.tsv
# Text file  293:     6822 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-293.tsv
# Text file  294:     4318 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-294.tsv
# Text file  295:     2450 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-295.tsv
# Text file  296:     2152 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-296.tsv
# Text file  297:     3563 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-297.tsv
# Text file  298:     3474 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-298.tsv
# Text file  299:     1023 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-299.tsv
# Text file  300:     4211 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-300.tsv
# Text file  301:     6021 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-301.tsv
# Text file  302:     2780 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-302.tsv
# Text file  303:     3715 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-303.tsv
# Text file  304:     9207 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-304.tsv
# Text file  305:     4839 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-305.tsv
# Text file  306:     3079 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-306.tsv
# Text file  307:     8289 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-307.tsv
# Text file  308:     3365 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-308.tsv
# Text file  309:     5918 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-309.tsv
# Text file  310:     5111 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-310.tsv
# Text file  311:     3512 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-311.tsv
# Text file  312:     6253 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-312.tsv
# Text file  313:     5245 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-313.tsv
# Text file  314:     1976 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-314.tsv
# Text file  315:      636 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-315.tsv
# Text file  316:     3915 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-316.tsv
# Text file  317:     3407 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-317.tsv
# Text file  318:     4371 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-318.tsv
# Text file  319:     2420 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-319.tsv
# Text file  320:     1582 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-320.tsv
# Text file  321:     3299 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-321.tsv
# Text file  322:     3608 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-322.tsv
# Text file  323:     3125 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-323.tsv
# Text file  324:     2368 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-324.tsv
# Text file  325:    10345 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-325.tsv
# Text file  326:     2988 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-326.tsv
# Text file  327:     5519 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-327.tsv
# Text file  328:      482 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-328.tsv
# Text file  329:     1724 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-329.tsv
# Text file  330:     4561 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-330.tsv
# Text file  331:     5638 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-331.tsv
# Text file  332:     4892 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-332.tsv
# Text file  333:     6753 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-333.tsv
# Text file  334:     1866 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-334.tsv
# Text file  335:     1819 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-335.tsv
# Text file  336:     4540 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-336.tsv
# Text file  337:     3840 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-337.tsv
# Text file  338:     4090 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-338.tsv
# Text file  339:     3823 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-339.tsv
# Text file  340:      933 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-340.tsv
# Text file  341:     5492 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-341.tsv
# Text file  342:     5447 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-342.tsv
# Text file  343:     2228 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-343.tsv
# Text file  344:     2700 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-344.tsv
# Text file  345:     3573 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-345.tsv
# Text file  346:     3086 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-346.tsv
# Text file  347:     2854 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-347.tsv
# Text file  348:     8419 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-348.tsv
# Text file  349:     6655 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-349.tsv
# Text file  350:     2501 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-350.tsv
# Text file  351:     3947 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-351.tsv
# Text file  352:     2348 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-352.tsv
# Text file  353:     3662 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-353.tsv
# Text file  354:     5879 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-354.tsv
# Text file  355:     2383 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-355.tsv
# Text file  356:     8052 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-356.tsv
# Text file  357:     2523 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-357.tsv
# Text file  358:     6072 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-358.tsv
# Text file  359:     7058 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-359.tsv
# Text file  360:     4022 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-360.tsv
# Text file  361:    10075 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-361.tsv
# Text file  362:     4267 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-362.tsv
# Text file  363:     6530 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-363.tsv
# Text file  364:     3666 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-364.tsv
# Text file  365:     3376 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-365.tsv
# Text file  366:     4210 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-366.tsv
# Text file  367:     4258 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-367.tsv
# Text file  368:     4109 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-368.tsv
# Text file  369:     4598 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-369.tsv
# Text file  370:     5499 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-370.tsv
# Text file  371:     4485 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-371.tsv
# Text file  372:     1906 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-372.tsv
# Text file  373:      571 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-373.tsv
# Text file  374:     2396 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-374.tsv
# Text file  375:     6035 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-375.tsv
# Text file  376:     4128 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-376.tsv
# Text file  377:     6071 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-377.tsv
# Text file  378:     3701 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-378.tsv
# Text file  379:     5537 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-379.tsv
# Text file  380:     3723 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-380.tsv
# Text file  381:     6828 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-381.tsv
# Text file  382:     2788 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-382.tsv
# Text file  383:     3690 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-383.tsv
# Text file  384:     2328 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-384.tsv
# Text file  385:     1949 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-385.tsv
# Text file  386:     2739 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-386.tsv
# Text file  387:     5247 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-387.tsv
# Text file  388:    10202 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-388.tsv
# Text file  389:     1260 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-389.tsv
# Text file  390:     5105 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-390.tsv
# Text file  391:     5095 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-391.tsv
# Text file  392:     4213 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-392.tsv
# Text file  393:     5054 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-393.tsv
# Text file  394:     8880 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-394.tsv
# Text file  395:     3863 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-395.tsv
# Text file  396:     9171 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-396.tsv
# Text file  397:     9148 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-397.tsv
# Text file  398:     7722 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-398.tsv
# Text file  399:     2345 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-399.tsv
# Text file  400:     7850 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-400.tsv
# Text file  401:     6375 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-401.tsv
# Text file  402:     4305 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-402.tsv
# Text file  403:     7544 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-403.tsv
# Text file  404:     3294 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-404.tsv
# Text file  405:     4555 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-405.tsv
# Text file  406:     5776 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-406.tsv
# Text file  407:     6634 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-407.tsv
# Text file  408:     7002 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-408.tsv
# Text file  409:     6468 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-409.tsv
# Text file  410:     3326 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-410.tsv
# Text file  411:     3441 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-411.tsv
# Text file  412:      599 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-412.tsv
# Text file  413:     6928 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-413.tsv
# Text file  414:     3883 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-414.tsv
# Text file  415:     6779 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-415.tsv
# Text file  416:     2052 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-416.tsv
# Text file  417:     3270 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-417.tsv
# Text file  418:     5383 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-418.tsv
# Text file  419:     5490 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-419.tsv
# Text file  420:     2217 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-420.tsv
# Text file  421:     1647 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-421.tsv
# Text file  422:     2749 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-422.tsv
# Text file  423:      871 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-423.tsv
# Text file  424:      729 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-424.tsv
# Text file  425:     1261 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-425.tsv
# Text file  426:     1614 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-426.tsv
# Text file  427:     1258 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-427.tsv
# Text file  428:     3859 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-428.tsv
# Text file  429:      563 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-429.tsv
# Text file  430:     8579 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-430.tsv
# Text file  431:     1395 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-431.tsv
# Text file  432:     9985 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-432.tsv
# Text file  433:     8020 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-433.tsv
# Text file  434:     3304 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-434.tsv
# Text file  435:     8492 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-435.tsv
# Text file  436:     5520 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-436.tsv
# Text file  437:     4475 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-437.tsv
# Text file  438:     2367 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-438.tsv
# Text file  439:     5775 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-439.tsv
# Text file  440:     4979 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-440.tsv
# Text file  441:     1508 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-441.tsv
# Text file  442:     3413 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-442.tsv
# Text file  443:     2402 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-443.tsv
# Text file  444:     1179 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-444.tsv
# Text file  445:     1339 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-445.tsv
# Text file  446:     2684 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-446.tsv
# Text file  447:     1838 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-447.tsv
# Text file  448:     1222 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-448.tsv
# Text file  449:     2760 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-449.tsv
# Text file  450:     5078 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-450.tsv
# Text file  451:     2993 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-451.tsv
# Text file  452:     1513 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-452.tsv
# Text file  453:     2555 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-453.tsv
# Text file  454:     2179 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-454.tsv
# Text file  455:     1417 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-455.tsv
# Text file  456:     3332 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-456.tsv
# Text file  457:     2037 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-457.tsv
# Text file  458:     3550 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-458.tsv
# Text file  459:     1400 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-459.tsv
# Text file  460:     1808 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-460.tsv
# Text file  461:     3206 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-461.tsv
# Text file  462:     1616 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-462.tsv
# Text file  463:     2590 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-463.tsv
# Text file  464:     6346 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-464.tsv
# Text file  465:     5018 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-465.tsv
# Text file  466:     1777 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-466.tsv
# Text file  467:     1952 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-467.tsv
# Text file  468:     4820 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-468.tsv
# Text file  469:     3917 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-469.tsv
# Text file  470:     3535 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-470.tsv
# Text file  471:     1915 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-471.tsv
# Text file  472:     1627 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-472.tsv
# Text file  473:     8100 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-473.tsv
# Text file  474:     6915 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-474.tsv
# Text file  475:     1420 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-475.tsv
# Text file  476:     2390 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-476.tsv
# Text file  477:     2097 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-477.tsv
# Text file  478:     2208 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-478.tsv
# Text file  479:     2264 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-479.tsv
# Text file  480:     2745 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-480.tsv
# Text file  481:     1637 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-481.tsv
# Text file  482:     2541 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-482.tsv
# Text file  483:     2446 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-483.tsv
# Text file  484:     2734 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-484.tsv
# ...
# Text file  786:     2742 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-786.tsv
# Text file  787:     3743 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-787.tsv
# Text file  788:     3273 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-788.tsv
# Text file  789:     2394 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-789.tsv
# Text file  790:     3557 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-790.tsv
# Text file  791:      457 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-791.tsv
# Text file  792:     3392 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-792.tsv
# Text file  793:     1548 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-793.tsv
# Text file  794:     1215 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-794.tsv
# Text file  795:     1127 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-795.tsv
# Text file  796:     1653 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-796.tsv
# Text file  797:     2535 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-797.tsv
# Text file  798:     6116 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-798.tsv
# Text file  799:     4578 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-799.tsv
# Text file  800:     9862 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-800.tsv
# Text file  801:     9380 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-801.tsv
# Text file  802:     2238 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-802.tsv
# Text file  803:     2237 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-803.tsv
# Text file  804:     4562 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-804.tsv
# Text file  805:     7849 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-805.tsv
# Text file  806:     2780 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-806.tsv
# Text file  807:     2257 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-807.tsv
# Text file  808:     3028 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-808.tsv
# Text file  809:     2824 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-809.tsv
# Text file  810:     3610 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-810.tsv
# Text file  811:     3178 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-811.tsv
# Text file  812:     3808 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-812.tsv
# Text file  813:     2435 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-813.tsv
# Text file  814:     1340 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-814.tsv
# Text file  815:     2839 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-815.tsv
# Text file  816:     2870 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-816.tsv
# Text file  817:     3312 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-817.tsv
# Text file  818:      840 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-818.tsv
# Text file  819:     2474 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-819.tsv
# Text file  820:     3738 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-820.tsv
# Text file  821:      591 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-821.tsv
# Text file  822:     6777 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-822.tsv
# Text file  823:     3474 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-823.tsv
# Text file  824:     2076 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-824.tsv
# Text file  825:     2529 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-825.tsv
# Text file  826:     1956 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-826.tsv
# Text file  827:     4188 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-827.tsv
# Text file  828:     3406 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-828.tsv
# Text file  829:     3674 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-829.tsv
# Text file  830:     3588 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-830.tsv
# Text file  831:     2980 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-831.tsv
# Text file  832:     1356 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-832.tsv
# Text file  833:     2491 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-833.tsv
# Text file  834:     2593 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-834.tsv
# Text file  835:     1019 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-835.tsv
# Text file  836:     2342 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-836.tsv
# Text file  837:      922 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-837.tsv
# Text file  838:     1592 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-838.tsv
# Text file  839:     4813 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-839.tsv
# Text file  840:     1421 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-840.tsv
# Text file  841:     2917 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-841.tsv
# Text file  842:     1805 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-842.tsv
# Text file  843:     2857 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-843.tsv
# Text file  844:     1618 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-844.tsv
# Text file  845:     1838 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-845.tsv
# Text file  846:     1191 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-846.tsv
# Text file  847:      879 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-847.tsv
# Text file  848:      369 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-848.tsv
# Text file  849:     1568 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-849.tsv
# Text file  850:     5468 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-850.tsv
# Text file  851:     1275 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-851.tsv
# Text file  852:     2109 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-852.tsv
# Text file  853:     4322 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-853.tsv
# Text file  854:     4448 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-854.tsv
# Text file  855:     1987 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-855.tsv
# Text file  856:     2795 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-856.tsv
# Text file  857:     2180 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-857.tsv
# Text file  858:     2556 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-858.tsv
# Text file  859:      975 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-859.tsv
# Text file  860:     1900 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-860.tsv
# Text file  861:     1133 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-861.tsv
# Text file  862:     1983 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-862.tsv
# Text file  863:     3750 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-863.tsv
# Text file  864:     1557 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-864.tsv
# Text file  865:     3138 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-865.tsv
# Text file  866:     2385 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-866.tsv
# Text file  867:     2261 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-867.tsv
# Text file  868:     3246 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-868.tsv
# Text file  869:     1645 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-869.tsv
# Text file  870:     1618 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-870.tsv
# Text file  871:     1079 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-871.tsv
# Text file  872:     1953 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-872.tsv
# Text file  873:     1844 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-873.tsv
# Text file  874:     1950 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-874.tsv
# Text file  875:     2177 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-875.tsv
# Text file  876:     1555 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-876.tsv
# Text file  877:     4286 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-877.tsv
# Text file  878:     2291 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-878.tsv
# Text file  879:     3544 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-879.tsv
# Text file  880:     1609 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-880.tsv
# Text file  881:     2259 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-881.tsv
# Text file  882:      731 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-882.tsv
# Text file  883:     1455 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-883.tsv
# Text file  884:     1144 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-884.tsv
# Text file  885:     1170 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-885.tsv
# Text file  886:     1265 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-886.tsv
# Text file  887:      863 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-887.tsv
# Text file  888:     1437 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-888.tsv
# Text file  889:     2686 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-889.tsv
# Text file  890:     1685 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-890.tsv
# Text file  891:     2042 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-891.tsv
# Text file  892:     1468 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-892.tsv
# Text file  893:     1647 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-893.tsv
# Text file  894:     3446 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-894.tsv
# Text file  895:      559 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-895.tsv
# Text file  896:     2719 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-896.tsv
# Text file  897:     1684 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-897.tsv
# Text file  898:     2260 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-898.tsv
# Text file  899:     1028 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-899.tsv
# Text file  900:     1281 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-900.tsv
# Text file  901:     2087 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-901.tsv
# Text file  902:     2554 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-902.tsv
# Text file  903:      437 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-903.tsv
# Text file  904:      842 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-904.tsv
# Text file  905:     1084 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-905.tsv
# Text file  906:      173 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-906.tsv
# Text file  907:     3434 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-907.tsv
# Text file  908:      298 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-908.tsv
# Text file  909:      187 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-909.tsv
# Text file  910:     3074 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-910.tsv
# Text file  911:     3979 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-911.tsv
# Text file  912:     1121 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-912.tsv
# Text file  913:     4451 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-913.tsv
# Text file  914:     1049 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-914.tsv
# Text file  915:      429 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-915.tsv
# Text file  916:      447 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-916.tsv
# Text file  917:      612 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-917.tsv
# Text file  918:      883 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-918.tsv
# Text file  919:      199 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-919.tsv
# Text file  920:     1227 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-920.tsv
# Text file  921:     1150 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-921.tsv
# Text file  922:     3108 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-922.tsv
# Text file  923:     3252 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-923.tsv
# Text file  924:      201 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-924.tsv
# Text file  925:     2329 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-925.tsv
# Text file  926:      713 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-926.tsv
# Text file  927:     1231 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-927.tsv
# Text file  928:    55287 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-928.tsv
# Text file  929:    27621 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-929.tsv
# Text file  930:    22954 segments to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/text-930.tsv
# Text files all:  3263186 segments to 931 files
# Anno file    1:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-1.tsv
# Anno file    2:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-2.tsv
# Anno file    3:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-3.tsv
# Anno file    4:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-4.tsv
# Anno file    5:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-5.tsv
# Anno file    6:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-6.tsv
# Anno file    7:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-7.tsv
# Anno file    8:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-8.tsv
# Anno file    9:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-9.tsv
# Anno file   10:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-10.tsv
# Anno file   11:   400000 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-11.tsv
# Anno file   12:   207016 annotations written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno-12.tsv
# Anno files all:  4607016 annotations to 12 files
# Slot mapping written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/pos2node.tsv
# Node mapping written to ~/gitlab.huc.knaw.nl/van-gogh/letters/watm/0.1.0/anno2node.tsv

# %% [markdown]
# # Step 8 Test the WATM against the TF

# %%
WA.error = False
WA.testAll()
# Out:
# Testing the text ...
# 	TF: 3263186
# 	WA: 3263186
# OK - whether the amounts of tokens agree
# 	TF: To Theo van Gogh. Th ... wart  Dutch artist
# 	WA: To Theo van Gogh. Th ... wart  Dutch artist
# OK - whether the text is the same
# Testing the elements ...
# 	TF: 500842
# 	WA: 500842
# OK - whether the amounts of elements and nodes agree
# Testing the processing instructions ...
# 	TF:      0
# 	WA:      0
# OK - whether the amounts of processing instructions agree
# Testing the element/pi annotations ...
# 	3764028 element/pi annotations
# 	Element      : 500842 x
# 	Pi           :      0 x
# 	Other        : 4106174 x
# 	Good name    : 500842 x
# 	Wrong name   :      0 x
# 	Good target  : 500842 x
# 	Wrong target :      0 x
# 	Unmapped     :      0 x
# OK - whether all element/pi annotations have good bodies
# OK - whether all element/pi annotations have good targets
# Testing the attributes ...
# 	938358 attribute values
# 	Good:     938358 x
# 	Wrong:        0 x
# OK - whether annotations are consistent with features
# 	WA attributes: 938358
# 	TF attributes: 938358
# OK - whether annotations are complete w.r.t. features
# Testing the format attributes ...
# 	2000062 format values
# 	formatting attributes:
# 		1925856 x indent
# 		 73155 x italics
# 		  1048 x super
# 		     2 x bold
# 		     1 x ss
# 	Good:     2000062 x
# 	Wrong:        0 x
# OK - whether format annotations are consistent with features
# 	WA format attributes: 2000062
# 	TF format attributes: 2000062
# OK - whether format annotations are complete w.r.t. features
# Testing the extra annotations ...
# 	0 extra feature values
# 	0 extra annotations
# OK - whether the extra annotations agree
# Testing the edges ...
# 	Found: 3764028 nodes
# 	Found edge link_ref with 29218 starting nodes
# 	Found edge link_target with 25277 starting nodes
# 	Found edge parent with 306779 starting nodes
# 	Checking edge parent
# 		same 306779 fromNodes
# 	OK - 306779 toNodes checked
# 	Checking edge link_ref
# 		same 29218 fromNodes
# 	OK - 30160 toNodes checked
# 	Checking edge link_target
# 		same 25277 fromNodes
# 	OK - 25277 toNodes checked
# OK - whether all edges agree
# Overall outcome ...
# OK - whether all tests passed
